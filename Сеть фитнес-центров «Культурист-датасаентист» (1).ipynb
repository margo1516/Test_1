# %% [markdown]
# # Проект: Сеть фитнес-центров «Культурист-датасаентист»

# %% [markdown]
# 1. Загрузка данных
# 2. Проведем исследовательский анализ данных (EDA)
# 3. Построим модель прогнозирования оттока клиентов
# 3.1 Логистическая регрессия
# 3.2 Случайный лес
# 4. Сделаю кластеризацию пользователей
# 5. Вывод

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

# %% [markdown]
# ## Загрузка данных

# %%
# Загрузим дадафрейм
df = pd.read_csv('/datasets/gym_churn.csv')
df
# Out:
#       gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0          1              1        1              1      0                6
# 1          0              1        0              0      1               12
# 2          0              1        1              0      1                1
# 3          0              1        1              1      1               12
# 4          1              1        1              1      1                1
# ...      ...            ...      ...            ...    ...              ...
# 3995       1              1        1              0      1               12
# 3996       0              1        0              0      1                1
# 3997       1              1        1              1      1               12
# 3998       0              1        1              1      1                6
# 3999       1              0        1              0      0               12
#
#       Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0                1   29                     14.227470                    5.0
# 1                1   31                    113.202938                   12.0
# 2                0   28                    129.448479                    1.0
# 3                1   33                     62.669863                   12.0
# 4                0   26                    198.362265                    1.0
# ...            ...  ...                           ...                    ...
# 3995             0   33                      2.406023                   12.0
# 3996             1   29                     68.883764                    1.0
# 3997             0   28                     78.250542                   11.0
# 3998             0   32                     61.912657                    5.0
# 3999             1   30                    178.861814                   12.0
#
#       Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# 0            3                   0.020398                           0.000000
# 1            7                   1.922936                           1.910244
# 2            2                   1.859098                           1.736502
# 3            2                   3.205633                           3.357215
# 4            3                   1.113884                           1.120078
# ...        ...                        ...                                ...
# 3995         8                   2.284497                           2.349070
# 3996         1                   1.277168                           0.292859
# 3997         2                   2.786146                           2.831439
# 3998         3                   1.630108                           1.596237
# 3999         1                   1.101832                           1.035270
#
#       Churn
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 3995      0
# 3996      1
# 3997      0
# 3998      0
# 3999      0
#
# [4000 rows x 14 columns]

# %%
df.sample(10)
# Out:
#       gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 3110       1              1        0              0      1                1
# 2547       0              1        0              0      1                1
# 1475       1              1        1              1      1               12
# 1513       1              0        0              0      1                6
# 2801       0              1        1              0      1                1
# 3177       1              1        1              1      1                6
# 1260       0              1        1              0      1                6
# 978        1              1        1              0      1                1
# 3650       1              1        1              0      1                1
# 2868       1              0        0              0      1                1
#
#       Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 3110             0   29                    101.989355                    1.0
# 2547             0   25                    372.059914                    1.0
# 1475             1   29                    187.011986                   11.0
# 1513             0   28                    116.284255                    6.0
# 2801             1   37                    223.876606                    1.0
# 3177             0   21                    134.689309                    6.0
# 1260             0   28                     53.653553                    6.0
# 978              0   32                    180.763590                    1.0
# 3650             0   30                     60.772568                    1.0
# 2868             1   29                    184.919215                    1.0
#
#       Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# 3110         9                   1.582775                           1.632240
# 2547         0                   1.777663                           1.117607
# 1475         4                   1.361240                           1.490380
# 1513         6                   2.709592                           2.665192
# 2801         1                   2.355656                           2.451223
# 3177         1                   1.982139                           2.720035
# 1260         4                   1.717337                           1.612709
# 978          1                   1.611664                           1.763303
# 3650         1                   0.917718                           0.555634
# 2868         1                   2.366217                           2.376640
#
#       Churn
# 3110      0
# 2547      1
# 1475      0
# 1513      0
# 2801      0
# 3177      1
# 1260      0
# 978       0
# 3650      1
# 2868      1

# %%
# просмотрю информацию
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
# gender                               4000 non-null int64
# Near_Location                        4000 non-null int64
# Partner                              4000 non-null int64
# Promo_friends                        4000 non-null int64
# Phone                                4000 non-null int64
# Contract_period                      4000 non-null int64
# Group_visits                         4000 non-null int64
# Age                                  4000 non-null int64
# Avg_additional_charges_total         4000 non-null float64
# Month_to_end_contract                4000 non-null float64
# Lifetime                             4000 non-null int64
# Avg_class_frequency_total            4000 non-null float64
# Avg_class_frequency_current_month    4000 non-null float64
# Churn                                4000 non-null int64
# dtypes: float64(4), int64(10)
# memory usage: 437.6 KB

# %%
# рассмотрю на столбцы
df.columns.tolist()
# Out:
# ['gender',
#  'Near_Location',
#  'Partner',
#  'Promo_friends',
#  'Phone',
#  'Contract_period',
#  'Group_visits',
#  'Age',
#  'Avg_additional_charges_total',
#  'Month_to_end_contract',
#  'Lifetime',
#  'Avg_class_frequency_total',
#  'Avg_class_frequency_current_month',
#  'Churn']

# %%
# приведу к нижнему регистру 
df.columns = [i.lower() for i in df]

# %%
# проверю столбцы
df.columns.tolist()
# Out:
# ['gender',
#  'near_location',
#  'partner',
#  'promo_friends',
#  'phone',
#  'contract_period',
#  'group_visits',
#  'age',
#  'avg_additional_charges_total',
#  'month_to_end_contract',
#  'lifetime',
#  'avg_class_frequency_total',
#  'avg_class_frequency_current_month',
#  'churn']

# %%
#посмотрим пропуски
df.isna().sum()
# Out:
# gender                               0
# near_location                        0
# partner                              0
# promo_friends                        0
# phone                                0
# contract_period                      0
# group_visits                         0
# age                                  0
# avg_additional_charges_total         0
# month_to_end_contract                0
# lifetime                             0
# avg_class_frequency_total            0
# avg_class_frequency_current_month    0
# churn                                0
# dtype: int64

# %%
# посмотрю дубликаты
df.duplicated().sum()
# Out:
# 0

# %%
# просмотрю сколько строк и колонок датафрейме
df.shape
# Out:
# (4000, 14)

# %% [markdown]
# # Вывод:
# пропусков дадафрайме нет, название столбцов привела в порядок, пропусков нет, дубликатов нет.
# датафрейме 4000 строк и 14 колонок

# %% [markdown]
# ## Проведем исследовательский анализ данных (EDA)

# %%
# посмотрим на среднее и стандартное отклонение
df.describe()
# Out:
#             gender  near_location      partner  promo_friends        phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        contract_period  group_visits          age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# 25%           1.000000      0.000000    27.000000
# 50%           1.000000      0.000000    29.000000
# 75%           6.000000      1.000000    31.000000
# max          12.000000      1.000000    41.000000
#
#        avg_additional_charges_total  month_to_end_contract     lifetime  \
# count                   4000.000000            4000.000000  4000.000000
# mean                     146.943728               4.322750     3.724750
# std                       96.355602               4.191297     3.749267
# min                        0.148205               1.000000     0.000000
# 25%                       68.868830               1.000000     1.000000
# 50%                      136.220159               1.000000     3.000000
# 75%                      210.949625               6.000000     5.000000
# max                      552.590740              12.000000    31.000000
#
#        avg_class_frequency_total  avg_class_frequency_current_month  \
# count                4000.000000                        4000.000000
# mean                    1.879020                           1.767052
# std                     0.972245                           1.052906
# min                     0.000000                           0.000000
# 25%                     1.180875                           0.963003
# 50%                     1.832768                           1.719574
# 75%                     2.536078                           2.510336
# max                     6.023668                           6.146783
#
#              churn
# count  4000.000000
# mean      0.265250
# std       0.441521
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# в age видно что возраст мин 18 лет мак 41 год, а вот std 3,25 это скорей всего люди блиского возраста.
# в contract_period мин 1 месяц мах 12, а вот std 4,5 оможно сказать что длительность абонемента меньше 12 месяцев,
# avg_additional_charges_total выручка от дополнительных услуг не велика, month_to_end_contract срок окончания у всех примерно одинаков, обонементы взяты на определенный период.
# Среднее посещение в неделю не так высоко, посещают не чаше 2-3 раз в неделю.
# Остальные данные нам бесполезны.

# %%
# средние значения признаков в двух группах
df.groupby('churn').agg('mean')
# Out:
#          gender  near_location   partner  promo_friends     phone  \
# churn
# 0      0.510037       0.873086  0.534195       0.353522  0.903709
# 1      0.510839       0.768143  0.355325       0.183789  0.902922
#
#        contract_period  group_visits        age  avg_additional_charges_total  \
# churn
# 0             5.747193      0.464103  29.976523                    158.445715
# 1             1.728558      0.268615  26.989632                    115.082899
#
#        month_to_end_contract  lifetime  avg_class_frequency_total  \
# churn
# 0                   5.283089  4.711807                   2.024876
# 1                   1.662582  0.990575                   1.474995
#
#        avg_class_frequency_current_month
# churn
# 0                               2.027882
# 1                               1.044546

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 15 columns):
# gender                               4000 non-null int64
# near_location                        4000 non-null int64
# partner                              4000 non-null int64
# promo_friends                        4000 non-null int64
# phone                                4000 non-null int64
# contract_period                      4000 non-null int64
# group_visits                         4000 non-null int64
# age                                  4000 non-null int64
# avg_additional_charges_total         4000 non-null float64
# month_to_end_contract                4000 non-null float64
# lifetime                             4000 non-null int64
# avg_class_frequency_total            4000 non-null float64
# avg_class_frequency_current_month    4000 non-null float64
# churn                                4000 non-null int64
# cluster                              4000 non-null int32
# dtypes: float64(4), int32(1), int64(10)
# memory usage: 453.2 KB

# %%
for column in df.columns:
    plt.figure(figsize=(5, 5))
    df.groupby('churn')[column]
    sns.distplot(df[column])
    plt.title(column)
    plt.show()

# %%
# построю boxplot
for column in ['gender', 'near_location', 'partner', 'promo_friends', 'contract_period', 'phone', 'group_visits', 'age', 'avg_additional_charges_total', 'month_to_end_contract', 'lifetime', 'avg_class_frequency_total', 'avg_class_frequency_current_month']:
    plt.figure(figsize=(5, 5))
    sns.boxplot(x = 'churn', y = df[column], data = df)
    plt.show()

# %%
# распределения
for column in ['gender', 'near_location', 'partner', 'promo_friends', 'contract_period', 'phone', 'group_visits', 'age', 'avg_additional_charges_total', 'month_to_end_contract', 'lifetime', 'avg_class_frequency_total', 'avg_class_frequency_current_month']:
    plt.figure(figsize=(5, 5))
    sns.countplot(x = df[column], hue='churn', data=df)
    plt.title(column)
    plt.show()

# %% [markdown]
# В близи проживают 0 группа, а вот 1 проживает дальше. Портнеры в обеих группах одинаковые, В рамках акции в 0 группе
# показатель выше. Длительность абонемента в 0 группе на 1 месяц больше, чем в первой, так же лучше показатели на период
# 6 и 12 месяцев у 0 группы. Наличие контактного телефона в обоих группах одинаковы, Групповые занятие обе группы посещают одинаково.
# Возраст в 0 группе больше, начинается с 23 -37 лет, а вот в 1 группе возрост от 18 до 35 лет.Первая группа более молодая.
# Выручка от других услуг в 0 группе чуть выше 1-ой. Срок окончания обонемента в 0 группе постоянный, в первой же нет.В ремя с момента
# обращение в цент у 0 группы более длительный чем в 1. в первой сразу проктически начинают ходить.Средня частота посещений в 0 группе
# 1 до 3, ав вот в 1 стабильно ходят 1-2 раза в неделю.

# %%
# матрица корреляции
cm = df.corr()
plt.figure(figsize=(14, 10))
sns.heatmap(cm, annot = True, fmt = '0.2f', linewidths=.5, cmap="PiYG")
plt.show()

# %% [markdown]
# Есть мультиколлинеарные признаки:
# contract_period - month_to_end_contract
# avg_class_frequency_current_month - avg_class_frequency_total
# Есть признаки с нулевой корреляцией с целевой переменной:
# phone
# gender

# %% [markdown]
# # 3. Построим модель прогнозирования оттока клиентов

# %% [markdown]
# Постройте модель бинарной классификации клиентов

# %% [markdown]
# # логистическая регрессия

# %%
X = df.drop(columns = ['churn'])
y = df['churn']

# %%
#разделяем модель на обучающую и валидационную выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) #ваш код здесь

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size = m, random_state = n )

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = model.predict(X_test)
probabilities =  model.predict_proba(X_test)[:,1]

# %%
print('Accuracy | Нет баланса классов: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, predictions)))
print('F1: {:.2f}'.format(f1_score(y_test, predictions)))
# Out:
# Accuracy | Нет баланса классов: 0.93
# Precision: 0.90
# Recall: 0.85
# F1: 0.88

# %% [markdown]
# # Случайный лес

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0) 
rf_model.fit(X_train_st, y_train)
rf_predictions = rf_model.predict(X_test_st) 
rf_probabilities = rf_model.predict_proba(X_test_st)[:,1]

# %%
print('Accuracy | Нет баланса классов: {:.2f}'.format(accuracy_score(y_test, rf_predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, rf_predictions)))
print('F1: {:.2f}'.format(f1_score(y_test, rf_predictions)))
# Out:
# Accuracy | Нет баланса классов: 0.92
# Precision: 0.89
# Recall: 0.82
# F1: 0.85

# %% [markdown]
# в Случайном лесе регрессия выглядит лучше.

# %% [markdown]
# #  4. Сделаю кластеризацию пользователей

# %%
df_sс = df.drop(['churn'], axis=1)
df_columns_list = df_sс.columns
df_sс = StandardScaler().fit_transform(df_sс)
df_sс = pd.DataFrame(df_sс, columns = df_columns_list).astype('float64')

# %%
# матрица расстояния
linked = linkage(df_sс, method = 'ward')

# %%
plt.figure(figsize=(16, 9))  
dendrogram(linked, orientation = 'top')
plt.title('Кластеризация пользователей')
plt.show()

# %%
# Обучу модель кластеризации на основании алгоритма K-Means, число кластеров принять 5
km = KMeans(n_clusters=5, random_state=0)
labels = km.fit_predict(df_sс)
df['cluster'] = labels

# %%
df.cluster.value_counts()
# Out:
# 3    1262
# 0    1011
# 4     837
# 2     505
# 1     385
# Name: cluster, dtype: int64

# %%
# посчитаю долю оттока
df.groupby('cluster').mean().T
# Out:
# cluster                                     0           1           2  \
# gender                               0.502473    0.522078    0.495050
# near_location                        0.959446    0.862338    0.000000
# partner                              0.783383    0.470130    0.463366
# promo_friends                        0.574679    0.306494    0.079208
# phone                                1.000000    0.000000    1.000000
# contract_period                     10.884273    4.787013    2.352475
# group_visits                         0.543027    0.425974    0.215842
# age                                 29.980218   29.301299   28.477228
# avg_additional_charges_total       160.706969  143.957664  135.457501
# month_to_end_contract                9.950544    4.475325    2.198020
# lifetime                             4.738872    3.924675    2.809901
# avg_class_frequency_total            1.983305    1.847220    1.660461
# avg_class_frequency_current_month    1.976225    1.716369    1.477324
# churn                                0.027695    0.267532    0.443564
#
# cluster                                     3           4
# gender                               0.485737    0.560335
# near_location                        1.000000    0.976105
# partner                              0.350238    0.356033
# promo_friends                        0.240095    0.229391
# phone                                1.000000    0.998805
# contract_period                      1.948494    2.665472
# group_visits                         0.341521    0.473118
# age                                 28.167987   30.127838
# avg_additional_charges_total       131.622204  161.724258
# month_to_end_contract                1.856577    2.455197
# lifetime                             2.440571    4.896057
# avg_class_frequency_total            1.247634    2.851531
# avg_class_frequency_current_month    1.012983    2.849473
# churn                                0.514263    0.068100

# %% [markdown]
# В среднем слабее оттекают кластеры 0 и 2.
# Живо оттекают из номера 3, одинаково из 1 и 4.

# %% [markdown]
# больший отток в 0 кластере.

# %%
# Построю распределения признаков для кластеров
for column in ['gender', 'near_location', 'partner', 'promo_friends', 'contract_period', 'phone', 'group_visits', 'age','avg_additional_charges_total','month_to_end_contract','lifetime', 'avg_class_frequency_total', 'avg_class_frequency_current_month']:
    plt.figure(figsize=(5, 5))
    sns.countplot(x = df[column], hue='cluster', data=df)
    plt.title(column)
    plt.show()

# %% [markdown]
# 'gender', 'near_location', 'partner', 'promo_friends', 'contract_period', 'phone', 'group_visits', 'age','avg_additional_charges_total','month_to_end_contract','lifetime', 'avg_class_frequency_total', 'avg_class_frequency_current_month'

# %%
for column in ['gender', 'near_location', 'partner', 'promo_friends', 'contract_period', 'phone', 'group_visits', 'age','avg_additional_charges_total','month_to_end_contract','lifetime', 'avg_class_frequency_total', 'avg_class_frequency_current_month']:
    plt.figure(figsize=(5, 3))
    sns.boxplot(x ='cluster',y = column, data = df)
    plt.show()

# %% [markdown]
# Проживают в близи только во втором кластере, Партнеры находятся в 1,2,3,4 кластере. В акции участвуют кластеры 0 и 1
# Обонемент в кластаре 1 и 4  берут в основном на срок до 6 месяцев, а вот телефонов ни у кого нет)
# в груповые везити в класстере 0,1,3,4 посещают охотнее чем во 2 класстере.
# Возраст почти везде одинаковый.
# суммарная выручка во всех кластерах проктически одинакова, срок до окончяние действия оьонемента в 0,1,4 класстере присутвует,
# а вот во 2 и3 скорей всего разовые посещение и в разнобой. в ремя с момента первого посещения проктически одинаковы, в 4 класстере чуть больше.
# Среднее часто посещения в неделю в 0,1,2,3 стабильна в среднем 2. а вот в 4 класстере среднее посещение 3

# %% [markdown]
# # 5. Вывод

# %% [markdown]
# Признаки "хороших кластеров":
# * возрастом — он больше
# * 2 кластер выделяется длительностью абонемента
# * оба кластера выделяются временем с момента первого обращения — ходят давно
# * большими расходами на доп. услуги
# * средняя частота посещений в неделю за предыдущий месяц у них тоже выже

# %% [markdown]
# * Для закупки трафика и привличения пользователей использовать лук-элайк аудитории из "хороших кластеров".
# * Поддерживать и мотивировать "хорошие кластеры".
# * Глубже сегментировать оттекающих, к каждому сегменту тестировать индивидуальные предложения.
# * Выстроить предиктивную систему аналитики и действовать не после оттока, а до него.
